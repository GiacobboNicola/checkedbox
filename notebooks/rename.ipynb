# %%
import os
import re
import shutil

# %%
classes = ["wrong","right", "empty"]
old_path = "../data/to_check/"
new_path = "../data/raw/"

# %%
"""
upload the existing jpg
"""
def get_existing(kind):
    jpgs = []
    for f in os.listdir(os.path.join(old_path,c)):
        parts = f.split("_")
        filename = "_".join(parts[:]) + "l.jpg"
        if(re.match(r".+_\.[0-9]+\.jpg", filename)):
            filename.replace(re.match(r".+_0\.[0-9]+\.jpg",".jpg"))
        jpgs.append(filename)
    return jpgs

# %%
for c in classes:
    print(f"---> {c}")
    old_jpgs = set()
    for f in os.listdir(os.path.join(old_path,c)):
        parts = f.replace(".jpg","").split("_")
        filename = "_".join(parts[:3])
        old_jpgs.add(filename)
    raw_path = os.path.join(new_path,c)
    for jpg in old_jpgs:
        if os.path.isfile(os.path.join(raw_path,jpg + "_n.jpg")):
            print("da aggiornare")
            os.rename(os.path.join(raw_path,jpg + "_n.jpg"),os.path.join(raw_path,jpg + "_s.jpg"))
        elif os.path.isfile(os.path.join(raw_path,jpg + "_s.jpg")):
            print("okay")
        elif os.path.isfile(os.path.join(raw_path,jpg + "_l.jpg")):
            print("boh")
        else:
            print(f"not found: {os.path.join(raw_path,jpg)}")

    print(len(old_jpgs))
# Out:
# ---> wrong
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# not found: ../data/raw/wrong/1484667_8_0
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# okay
# not found: ../data/raw/wrong/1484745_2_0
# okay
# okay
# okay
# okay
# okay
# okay
# ...
